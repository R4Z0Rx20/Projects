# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

import math
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\KIIT\.conda\envs\dl\Lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.12.2 when it was built against 1.12.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %% [markdown]
# # Loading Data

# %%
df = pd.read_csv('GOOGL.csv')

# %%
df.head()
# Out:
#      datetime       open       high        low      close    volume
# 0  2023-10-11  138.58000  141.11000  138.58000  140.55000  25850200
# 1  2023-10-10  138.50000  139.72000  137.33000  138.06000  27786600
# 2  2023-10-09  136.94000  138.94000  135.61000  138.42000  19278100
# 3  2023-10-06  134.00999  138.16000  134.00999  137.58000  27583200
# 4  2023-10-05  135.07001  135.49001  133.45000  135.07001  19832600

# %% [markdown]
# # Data Preprocessing

# %%
data = df['close'].loc[df['datetime']>'2010-01-01'].reset_index(drop=True)

# %%
data = data[::-1]

# %%
data = data.reset_index(drop = True)

# %%
data.head()
# Out:
# 0    15.68443
# 1    15.61537
# 2    15.22172
# 3    14.86737
# 4    15.06557
# Name: close, dtype: float64

# %%
data.tail()
# Out:
# 3462    135.07001
# 3463    137.58000
# 3464    138.42000
# 3465    138.06000
# 3466    140.55000
# Name: close, dtype: float64

# %%
plt.plot(data)

# %%
stdscaler = StandardScaler()

# %%
data = stdscaler.fit_transform(np.array(data).reshape(-1,1))

# %%
training_size = int(0.8*len(data[:, 0]))
test_size = len(data[:, 0]) - training_size

# %%
training_size, test_size
# Out:
# (2773, 694)

# %%
train_data = data[0: training_size]
test_data = data[training_size: len(data[:, 0])]

# %%
def XySplit(data, time_window = 20):
    X = []
    y = []
    for i in range(0, len(data[:, 0])-time_window-1):
        X.append(data[i:i+time_window, 0])
        y.append(data[i+time_window, 0])
    return np.array(X), np.array(y)

# %%
time_window = 100

# %%
X_train, y_train = XySplit(train_data, time_window)
X_test, y_test = XySplit(test_data, time_window)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2672, 100), (2672,), (593, 100), (593,))

# %%
X_train =X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Model

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(time_window,1)))
model.add(Dropout(0.5))
model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(50))
model.add(Dropout(0.5))
model.add(Dense(1))

# %%
model.compile(loss ='mean_squared_error', optimizer = Adam(learning_rate = 0.0001))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
def trainer(epochs, verbose):
    model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=epochs, batch_size=64, verbose=verbose)

# %%
def report():
    train_predict=stdscaler.inverse_transform(model.predict(X_train))
    test_predict=stdscaler.inverse_transform(model.predict(X_test))
    
    print(f'\n\nTrain RMSE Loss: {math.sqrt(mean_squared_error(y_train,train_predict))}')
    print(f'\n\nTest RMSE Loss: {math.sqrt(mean_squared_error(y_test,test_predict))}\n\n')
    print(f'\n\nTest MAPE Loss: {mean_absolute_percentage_error(y_test, test_predict)}\n\n')
    
    
    trainPredictPlot = np.empty_like(data)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[time_window:len(train_predict)+time_window, :] = train_predict

    testPredictPlot = np.empty_like(data)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(train_predict)+(time_window*2)+1:len(data)-1, :] = test_predict
    
    plt.plot(stdscaler.inverse_transform(data), color = 'black')
    plt.plot(trainPredictPlot, color = 'blue')
    plt.plot(testPredictPlot, color = 'red')
    plt.legend(['Actual Data', 'Train Predict', 'Test Predict'])
    plt.title('Actual vs Predicted values')
    plt.figure(figsize = (19, 10))
    plt.show()
    
    plt.plot(stdscaler.inverse_transform(y_test.reshape(-1,1)), color = 'black')
    plt.plot(test_predict, color = 'red')
    plt.legend(['Actual Data', 'Test Predict'])
    plt.title('Actual Testing vs Predicted Testing values')
    plt.figure(figsize = (19, 10))
    plt.show()

# %%
trainer(100, 1)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 12s 184ms/step - loss: 0.2432 - val_loss: 2.1129
# Epoch 2/100
# 42/42 [==============================] - 8s 198ms/step - loss: 0.0477 - val_loss: 1.6581
# Epoch 3/100
# 42/42 [==============================] - 11s 264ms/step - loss: 0.0337 - val_loss: 1.2661
# Epoch 4/100
# 42/42 [==============================] - 11s 260ms/step - loss: 0.0268 - val_loss: 0.8913
# Epoch 5/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0227 - val_loss: 0.7075
# Epoch 6/100
# 42/42 [==============================] - 11s 251ms/step - loss: 0.0224 - val_loss: 0.6074
# Epoch 7/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0203 - val_loss: 0.5189
# Epoch 8/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0192 - val_loss: 0.4864
# Epoch 9/100
# 42/42 [==============================] - 11s 251ms/step - loss: 0.0188 - val_loss: 0.3997
# Epoch 10/100
# 42/42 [==============================] - 11s 251ms/step - loss: 0.0177 - val_loss: 0.4048
# Epoch 11/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0174 - val_loss: 0.3593
# Epoch 12/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0177 - val_loss: 0.3477
# Epoch 13/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0175 - val_loss: 0.2853
# Epoch 14/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0165 - val_loss: 0.3067
# Epoch 15/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0166 - val_loss: 0.2560
# Epoch 16/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0158 - val_loss: 0.2642
# Epoch 17/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0158 - val_loss: 0.2427
# Epoch 18/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0160 - val_loss: 0.2598
# Epoch 19/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0157 - val_loss: 0.2342
# Epoch 20/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0148 - val_loss: 0.2242
# Epoch 21/100
# 42/42 [==============================] - 11s 252ms/step - loss: 0.0164 - val_loss: 0.1862
# Epoch 22/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0150 - val_loss: 0.1759
# Epoch 23/100
# 42/42 [==============================] - 11s 257ms/step - loss: 0.0151 - val_loss: 0.1601
# Epoch 24/100
# 42/42 [==============================] - 11s 255ms/step - loss: 0.0150 - val_loss: 0.1370
# Epoch 25/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0144 - val_loss: 0.1622
# Epoch 26/100
# 42/42 [==============================] - 11s 261ms/step - loss: 0.0145 - val_loss: 0.1294
# Epoch 27/100
# 42/42 [==============================] - 11s 259ms/step - loss: 0.0142 - val_loss: 0.1212
# Epoch 28/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0138 - val_loss: 0.1256
# Epoch 29/100
# 42/42 [==============================] - 11s 258ms/step - loss: 0.0143 - val_loss: 0.0983
# Epoch 30/100
# 42/42 [==============================] - 11s 258ms/step - loss: 0.0143 - val_loss: 0.0883
# Epoch 31/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0154 - val_loss: 0.0762
# Epoch 32/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0130 - val_loss: 0.0714
# Epoch 33/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0137 - val_loss: 0.0810
# Epoch 34/100
# 42/42 [==============================] - 11s 252ms/step - loss: 0.0137 - val_loss: 0.0710
# Epoch 35/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0139 - val_loss: 0.0656
# Epoch 36/100
# 42/42 [==============================] - 11s 256ms/step - loss: 0.0130 - val_loss: 0.0583
# Epoch 37/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0132 - val_loss: 0.0699
# Epoch 38/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0125 - val_loss: 0.0616
# Epoch 39/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0124 - val_loss: 0.0483
# Epoch 40/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0132 - val_loss: 0.0504
# Epoch 41/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0131 - val_loss: 0.0416
# Epoch 42/100
# 42/42 [==============================] - 11s 256ms/step - loss: 0.0125 - val_loss: 0.0362
# Epoch 43/100
# 42/42 [==============================] - 11s 268ms/step - loss: 0.0123 - val_loss: 0.0334
# Epoch 44/100
# 42/42 [==============================] - 11s 270ms/step - loss: 0.0124 - val_loss: 0.0458
# Epoch 45/100
# 42/42 [==============================] - 11s 265ms/step - loss: 0.0128 - val_loss: 0.0344
# Epoch 46/100
# 42/42 [==============================] - 11s 254ms/step - loss: 0.0121 - val_loss: 0.0399
# Epoch 47/100
# 42/42 [==============================] - 11s 252ms/step - loss: 0.0124 - val_loss: 0.0254
# Epoch 48/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0125 - val_loss: 0.0236
# Epoch 49/100
# 42/42 [==============================] - 11s 258ms/step - loss: 0.0124 - val_loss: 0.0234
# Epoch 50/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0122 - val_loss: 0.0235
# Epoch 51/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0116 - val_loss: 0.0252
# Epoch 52/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0122 - val_loss: 0.0243
# Epoch 53/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0116 - val_loss: 0.0226
# Epoch 54/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0115 - val_loss: 0.0225
# Epoch 55/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0122 - val_loss: 0.0238
# Epoch 56/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0114 - val_loss: 0.0232
# Epoch 57/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0109 - val_loss: 0.0235
# Epoch 58/100
# 42/42 [==============================] - 11s 252ms/step - loss: 0.0110 - val_loss: 0.0237
# Epoch 59/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0120 - val_loss: 0.0222
# Epoch 60/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0115 - val_loss: 0.0226
# Epoch 61/100
# 42/42 [==============================] - 11s 256ms/step - loss: 0.0117 - val_loss: 0.0219
# Epoch 62/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0115 - val_loss: 0.0240
# Epoch 63/100
# 42/42 [==============================] - 12s 279ms/step - loss: 0.0109 - val_loss: 0.0227
# Epoch 64/100
# 42/42 [==============================] - 11s 259ms/step - loss: 0.0114 - val_loss: 0.0220
# Epoch 65/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0115 - val_loss: 0.0233
# Epoch 66/100
# 42/42 [==============================] - 11s 267ms/step - loss: 0.0112 - val_loss: 0.0225
# Epoch 67/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0106 - val_loss: 0.0217
# Epoch 68/100
# 42/42 [==============================] - 11s 251ms/step - loss: 0.0111 - val_loss: 0.0231
# Epoch 69/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0115 - val_loss: 0.0224
# Epoch 70/100
# 42/42 [==============================] - 11s 268ms/step - loss: 0.0114 - val_loss: 0.0233
# Epoch 71/100
# 42/42 [==============================] - 11s 271ms/step - loss: 0.0109 - val_loss: 0.0223
# Epoch 72/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0111 - val_loss: 0.0214
# Epoch 73/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0112 - val_loss: 0.0212
# Epoch 74/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0112 - val_loss: 0.0292
# Epoch 75/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0108 - val_loss: 0.0311
# Epoch 76/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0111 - val_loss: 0.0260
# Epoch 77/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0109 - val_loss: 0.0231
# Epoch 78/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0112 - val_loss: 0.0294
# Epoch 79/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0111 - val_loss: 0.0256
# Epoch 80/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0109 - val_loss: 0.0266
# Epoch 81/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0106 - val_loss: 0.0312
# Epoch 82/100
# 42/42 [==============================] - 11s 266ms/step - loss: 0.0107 - val_loss: 0.0515
# Epoch 83/100
# 42/42 [==============================] - 11s 255ms/step - loss: 0.0107 - val_loss: 0.0228
# Epoch 84/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0104 - val_loss: 0.0236
# Epoch 85/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0112 - val_loss: 0.0514
# Epoch 86/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0100 - val_loss: 0.0599
# Epoch 87/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0107 - val_loss: 0.0312
# Epoch 88/100
# 42/42 [==============================] - 11s 257ms/step - loss: 0.0102 - val_loss: 0.0451
# Epoch 89/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0106 - val_loss: 0.0412
# Epoch 90/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0106 - val_loss: 0.0508
# Epoch 91/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0109 - val_loss: 0.0266
# Epoch 92/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0105 - val_loss: 0.0313
# Epoch 93/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0106 - val_loss: 0.0300
# Epoch 94/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0108 - val_loss: 0.0482
# Epoch 95/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0104 - val_loss: 0.0251
# Epoch 96/100
# 42/42 [==============================] - 11s 257ms/step - loss: 0.0102 - val_loss: 0.0363
# Epoch 97/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0101 - val_loss: 0.0312
# Epoch 98/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0101 - val_loss: 0.0269
# Epoch 99/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0102 - val_loss: 0.0330
# Epoch 100/100
# 42/42 [==============================] - 11s 257ms/step - loss: 0.0103 - val_loss: 0.0225

# %% [markdown]
# # Result Analysis

# %%
report()
# Out:
# 84/84 [==============================] - 3s 27ms/step
# 19/19 [==============================] - 1s 27ms/step
#
#
# Train RMSE Loss: 42.306807104247085
#
#
# Test RMSE Loss: 120.186529630689

# %%
model.save('GOOGLmodel.h5')
# Out:
# C:\Users\KIIT\.conda\envs\dl\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
epochs_list = [25, 50]

# %%
for epochs in epochs_list:
    print(f'epochs: {epochs}')
    trainer(epochs, 0)
    report()
# Out:
# epochs: 25
# 84/84 [==============================] - 5s 40ms/step
# 19/19 [==============================] - 1s 40ms/step
#
#
# Train RMSE Loss: 42.510311264386516
#
#
# Test RMSE Loss: 104.50951468794871
#
#
#
#
# Test MAPE Loss: 62.04097744414024
# epochs: 50
# 84/84 [==============================] - 4s 42ms/step
# 19/19 [==============================] - 1s 41ms/step
#
#
# Train RMSE Loss: 42.2764276217418
#
#
# Test RMSE Loss: 115.66662254470901
#
#
#
#
# Test MAPE Loss: 67.43099971330086

# %%
model = load_model("GOOGLmodel.h5")

# %%
report()
# Out:
# 84/84 [==============================] - 3s 27ms/step
# 19/19 [==============================] - 1s 28ms/step
#
#
# Train RMSE Loss: 42.306807104247085
#
#
# Test RMSE Loss: 120.186529630689
#
#
#
#
# Test MAPE Loss: 69.30883422213356

# %%
loaded_model = load_model("GOOGLmodel.h5")

# %%
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#R4Z0Rx
