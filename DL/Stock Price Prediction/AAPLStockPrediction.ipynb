# %% [markdown]
# # Importing Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam
from keras.models import load_model

import math
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\KIIT\.conda\envs\dl\Lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.12.2 when it was built against 1.12.1, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %% [markdown]
# # Loading Data

# %%
df = pd.read_csv('AAPL.csv')

# %%
df.head()
# Out:
#          Date      Open      High       Low     Close     Volume
# 0  1980-12-12  0.128348  0.128906  0.128348  0.128348  469033600
# 1  1980-12-15  0.122210  0.122210  0.121652  0.121652  175884800
# 2  1980-12-16  0.113281  0.113281  0.112723  0.112723  105728000
# 3  1980-12-17  0.115513  0.116071  0.115513  0.115513   86441600
# 4  1980-12-18  0.118862  0.119420  0.118862  0.118862   73449600

# %% [markdown]
# # Data Preprocessing

# %%
data = df['Close'].loc[df['Date']>'2010-01-01'].reset_index(drop=True)

# %%
data.head()
# Out:
# 0    7.643214
# 1    7.656429
# 2    7.534643
# 3    7.520714
# 4    7.570714
# Name: Close, dtype: float64

# %%
data.tail()
# Out:
# 3459    173.75000
# 3460    172.39999
# 3461    173.66000
# 3462    174.91000
# 3463    177.49001
# Name: Close, dtype: float64

# %%
plt.plot(data)

# %%
stdscaler = StandardScaler()

# %%
data = stdscaler.fit_transform(np.array(data).reshape(-1,1))

# %%
training_size = int(0.8*len(data[:, 0]))
test_size = len(data[:, 0]) - training_size

# %%
training_size, test_size
# Out:
# (2771, 693)

# %%
train_data = data[0: training_size]
test_data = data[training_size: len(data[:, 0])]

# %%
def XySplit(data, time_window = 20):
    X = []
    y = []
    for i in range(0, len(data[:, 0])-time_window-1):
        X.append(data[i:i+time_window, 0])
        y.append(data[i+time_window, 0])
    return np.array(X), np.array(y)

# %%
time_window = 100

# %%
X_train, y_train = XySplit(train_data, time_window)
X_test, y_test = XySplit(test_data, time_window)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((2670, 100), (2670,), (592, 100), (592,))

# %%
X_train =X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# # Model

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(time_window,1)))
model.add(Dropout(0.5))
model.add(LSTM(50,return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(50))
model.add(Dropout(0.5))
model.add(Dense(1))

# %%
model.compile(loss ='mean_squared_error', optimizer = Adam(learning_rate = 0.0001))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
def trainer(epochs, verbose):
    model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=epochs, batch_size=64, verbose=verbose)

# %%
def report():
    train_predict=stdscaler.inverse_transform(model.predict(X_train))
    test_predict=stdscaler.inverse_transform(model.predict(X_test))
    
    print(f'\n\nTrain RMSE Loss: {math.sqrt(mean_squared_error(y_train,train_predict))}')
    print(f'\n\nTest RMSE Loss: {math.sqrt(mean_squared_error(y_test,test_predict))}')
    print(f'\n\nTest MAPE Loss: {mean_absolute_percentage_error(y_test, test_predict)}\n\n')
    
    
    trainPredictPlot = np.empty_like(data)
    trainPredictPlot[:, :] = np.nan
    trainPredictPlot[time_window:len(train_predict)+time_window, :] = train_predict

    testPredictPlot = np.empty_like(data)
    testPredictPlot[:, :] = np.nan
    testPredictPlot[len(train_predict)+(time_window*2)+1:len(data)-1, :] = test_predict
    
    plt.plot(stdscaler.inverse_transform(data), color = 'black')
    plt.plot(trainPredictPlot, color = 'blue')
    plt.plot(testPredictPlot, color = 'red')
    plt.legend(['Actual Data', 'Train Predict', 'Test Predict'])
    plt.title('Actual vs Predicted values')
    plt.figure(figsize = (19, 10))
    plt.show()
    
    plt.plot(stdscaler.inverse_transform(y_test.reshape(-1,1)), color = 'black')
    plt.plot(test_predict, color = 'red')
    plt.legend(['Actual Data', 'Test Predict'])
    plt.title('Actual Testing vs Predicted Testing values')
    plt.figure(figsize = (19, 10))
    plt.show()

# %%
trainer(100, 1)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 9s 226ms/step - loss: 0.0086 - val_loss: 0.0309
# Epoch 2/100
# 42/42 [==============================] - 11s 256ms/step - loss: 0.0098 - val_loss: 0.0701
# Epoch 3/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0092 - val_loss: 0.0301
# Epoch 4/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0102 - val_loss: 0.0263
# Epoch 5/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0090 - val_loss: 0.0377
# Epoch 6/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0100 - val_loss: 0.0299
# Epoch 7/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0085 - val_loss: 0.0289
# Epoch 8/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0089 - val_loss: 0.0508
# Epoch 9/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0090 - val_loss: 0.0304
# Epoch 10/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0102 - val_loss: 0.0184
# Epoch 11/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0091 - val_loss: 0.0275
# Epoch 12/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0103 - val_loss: 0.0198
# Epoch 13/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0096 - val_loss: 0.0369
# Epoch 14/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0083 - val_loss: 0.0356
# Epoch 15/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0088 - val_loss: 0.0239
# Epoch 16/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0089 - val_loss: 0.0158
# Epoch 17/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0095 - val_loss: 0.0273
# Epoch 18/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0093 - val_loss: 0.0288
# Epoch 19/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0088 - val_loss: 0.0229
# Epoch 20/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0088 - val_loss: 0.0283
# Epoch 21/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0086 - val_loss: 0.0228
# Epoch 22/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0091 - val_loss: 0.0400
# Epoch 23/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0088 - val_loss: 0.0366
# Epoch 24/100
# 42/42 [==============================] - 11s 255ms/step - loss: 0.0087 - val_loss: 0.0243
# Epoch 25/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0081 - val_loss: 0.0165
# Epoch 26/100
# 42/42 [==============================] - 11s 254ms/step - loss: 0.0088 - val_loss: 0.0429
# Epoch 27/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0083 - val_loss: 0.0325
# Epoch 28/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0085 - val_loss: 0.0231
# Epoch 29/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0081 - val_loss: 0.0259
# Epoch 30/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0083 - val_loss: 0.0154
# Epoch 31/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0085 - val_loss: 0.0455
# Epoch 32/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0081 - val_loss: 0.0382
# Epoch 33/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0086 - val_loss: 0.0331
# Epoch 34/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0089 - val_loss: 0.0193
# Epoch 35/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0086 - val_loss: 0.0710
# Epoch 36/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0085 - val_loss: 0.0434
# Epoch 37/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0079 - val_loss: 0.0660
# Epoch 38/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0084 - val_loss: 0.0329
# Epoch 39/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0079 - val_loss: 0.0349
# Epoch 40/100
# 42/42 [==============================] - 11s 269ms/step - loss: 0.0083 - val_loss: 0.0209
# Epoch 41/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0078 - val_loss: 0.0206
# Epoch 42/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0084 - val_loss: 0.0141
# Epoch 43/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0075 - val_loss: 0.0209
# Epoch 44/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0077 - val_loss: 0.0373
# Epoch 45/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0077 - val_loss: 0.0296
# Epoch 46/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0079 - val_loss: 0.0166
# Epoch 47/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0081 - val_loss: 0.0212
# Epoch 48/100
# 42/42 [==============================] - 12s 277ms/step - loss: 0.0079 - val_loss: 0.0238
# Epoch 49/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0080 - val_loss: 0.0448
# Epoch 50/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0081 - val_loss: 0.0261
# Epoch 51/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0079 - val_loss: 0.0507
# Epoch 52/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0078 - val_loss: 0.0221
# Epoch 53/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0076 - val_loss: 0.0180
# Epoch 54/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0079 - val_loss: 0.0409
# Epoch 55/100
# 42/42 [==============================] - 11s 259ms/step - loss: 0.0088 - val_loss: 0.0228
# Epoch 56/100
# 42/42 [==============================] - 11s 253ms/step - loss: 0.0078 - val_loss: 0.0134
# Epoch 57/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0081 - val_loss: 0.0195
# Epoch 58/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0070 - val_loss: 0.0284
# Epoch 59/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0080 - val_loss: 0.0324
# Epoch 60/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0077 - val_loss: 0.0466
# Epoch 61/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0080 - val_loss: 0.0146
# Epoch 62/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0081 - val_loss: 0.0425
# Epoch 63/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0073 - val_loss: 0.0253
# Epoch 64/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0075 - val_loss: 0.0194
# Epoch 65/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0076 - val_loss: 0.0278
# Epoch 66/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0077 - val_loss: 0.0420
# Epoch 67/100
# 42/42 [==============================] - 11s 251ms/step - loss: 0.0073 - val_loss: 0.0314
# Epoch 68/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0076 - val_loss: 0.0196
# Epoch 69/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0074 - val_loss: 0.0462
# Epoch 70/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0071 - val_loss: 0.0214
# Epoch 71/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0071 - val_loss: 0.0141
# Epoch 72/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0074 - val_loss: 0.0132
# Epoch 73/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0081 - val_loss: 0.0217
# Epoch 74/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0074 - val_loss: 0.0410
# Epoch 75/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0075 - val_loss: 0.0284
# Epoch 76/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0071 - val_loss: 0.0300
# Epoch 77/100
# 42/42 [==============================] - 10s 248ms/step - loss: 0.0076 - val_loss: 0.0149
# Epoch 78/100
# 42/42 [==============================] - 11s 252ms/step - loss: 0.0076 - val_loss: 0.0166
# Epoch 79/100
# 42/42 [==============================] - 10s 250ms/step - loss: 0.0071 - val_loss: 0.0255
# Epoch 80/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0067 - val_loss: 0.0139
# Epoch 81/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0072 - val_loss: 0.0401
# Epoch 82/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0072 - val_loss: 0.0297
# Epoch 83/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0077 - val_loss: 0.0420
# Epoch 84/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0070 - val_loss: 0.0280
# Epoch 85/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0075 - val_loss: 0.0234
# Epoch 86/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0070 - val_loss: 0.0293
# Epoch 87/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0073 - val_loss: 0.0533
# Epoch 88/100
# 42/42 [==============================] - 10s 241ms/step - loss: 0.0066 - val_loss: 0.0484
# Epoch 89/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0082 - val_loss: 0.0548
# Epoch 90/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0074 - val_loss: 0.0150
# Epoch 91/100
# 42/42 [==============================] - 10s 245ms/step - loss: 0.0067 - val_loss: 0.0245
# Epoch 92/100
# 42/42 [==============================] - 10s 246ms/step - loss: 0.0067 - val_loss: 0.0310
# Epoch 93/100
# 42/42 [==============================] - 10s 243ms/step - loss: 0.0073 - val_loss: 0.0242
# Epoch 94/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0068 - val_loss: 0.0518
# Epoch 95/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0067 - val_loss: 0.0220
# Epoch 96/100
# 42/42 [==============================] - 10s 242ms/step - loss: 0.0068 - val_loss: 0.0150
# Epoch 97/100
# 42/42 [==============================] - 10s 244ms/step - loss: 0.0074 - val_loss: 0.0506
# Epoch 98/100
# 42/42 [==============================] - 12s 287ms/step - loss: 0.0074 - val_loss: 0.0289
# Epoch 99/100
# 42/42 [==============================] - 10s 249ms/step - loss: 0.0065 - val_loss: 0.0444
# Epoch 100/100
# 42/42 [==============================] - 10s 247ms/step - loss: 0.0067 - val_loss: 0.0294

# %% [markdown]
# # Result Analysis

# %%
report()
# Out:
# 84/84 [==============================] - 2s 29ms/step
# 19/19 [==============================] - 1s 29ms/step
#
#
# Train RMSE Loss: 43.02309913517294
#
#
# Test RMSE Loss: 149.75610540197206
#
#
# Test MAPE Loss: 80.90190724861297

# %%
model.save('AAPLmodel.h5')
# Out:
# C:\Users\KIIT\.conda\envs\dl\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # Tested Models

# %% [markdown]
# model=Sequential()
# model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
# model.add(LSTM(50,return_sequences=True))
# model.add(LSTM(50))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error',optimizer='adam')
#
# lr = 0.001
#
# train loss: 42.53407718394477
#
# test loss: 147.45663506622907
#
# ![image.png](attachment:image.png)
#
# model=Sequential()
# model.add(LSTM(50,return_sequences=True,input_shape=(time_window,1)))
# model.add(Dropout(0.25))
# model.add(LSTM(25,return_sequences=True))
# model.add(Dropout(0.25))
# model.add(LSTM(25))
# model.add(Dropout(0.25))
# model.add(Dense(1))
#
# lr = 0.0001
#
# train_loss: 42.52218436865986
#
# test_loss: 140.759728056867
#
# ![image-2.png](attachment:image-2.png)
#
# model=Sequential()
# model.add(LSTM(50,return_sequences=True,input_shape=(time_window,1)))
# model.add(Dropout(0.25))
# model.add(LSTM(50,return_sequences=True))
# model.add(Dropout(0.25))
# model.add(LSTM(50))
# model.add(Dropout(0.25))
# model.add(Dense(1))
#
# lr = 0.0001
#
# train_loss: 42.357468163747015
#
# test_loss: 150.1653993070135
#
# ![image-3.png](attachment:image-3.png)
#
# model=Sequential()
# model.add(LSTM(50,return_sequences=True,input_shape=(time_window,1)))
# model.add(Dropout(0.5))
# model.add(LSTM(50,return_sequences=True))
# model.add(Dropout(0.5))
# model.add(LSTM(50))
# model.add(Dropout(0.5))
# model.add(Dense(1))
#
# lr = 0.0001
#
# train_loss: 42.74031398132778
#
# test_loss: 150.3392457216271
#
# ![image-4.png](attachment:image-4.png)

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('StockModel4.h5')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 100, 50)           10400
#
#  dropout_6 (Dropout)         (None, 100, 50)           0
#
#  lstm_7 (LSTM)               (None, 100, 50)           20200
#
#  dropout_7 (Dropout)         (None, 100, 50)           0
#
#  lstm_8 (LSTM)               (None, 50)                20200
#
#  dropout_8 (Dropout)         (None, 50)                0
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs_list = [25, 50]

# %%
for epochs in epochs_list:
    print(f'epochs: {epochs}')
    trainer(epochs, 0)
    report()
# Out:
# epochs: 25
# 84/84 [==============================] - 5s 39ms/step
# 19/19 [==============================] - 1s 41ms/step
#
#
# Train RMSE Loss: 42.936617368862144
#
#
# Test RMSE Loss: 145.95711319986503
#
#
# Test MAPE Loss: 79.28149626026303
# epochs: 50
# 84/84 [==============================] - 4s 42ms/step
# 19/19 [==============================] - 1s 41ms/step
#
#
# Train RMSE Loss: 42.1614549779608
#
#
# Test RMSE Loss: 147.97395590445876
#
#
# Test MAPE Loss: 79.98094562720274

# %%
loaded_model = load_model("AAPLmodel.h5")

# %%
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  dropout (Dropout)           (None, 100, 50)           0
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dropout_2 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 50851 (198.64 KB)
# Trainable params: 50851 (198.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#R4Z0Rx
